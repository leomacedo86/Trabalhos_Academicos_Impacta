# %% [markdown]
# ### 1) Para cada marca(Brand) de produto:
# ##### Baixe os dados via REST
# #### Escoha 5 marcas e Salve um csv com o nome de cada marca
# #### Crie um gráfico com a quantidade de produtos por marca

# %% [markdown]
# ## IMPORTS

# %%
import requests
import pandas as pd
import seaborn as sns
from matplotlib            import pyplot as plt

# %% [markdown]
# ### MARCA  1 - MAYBELLINE

# %%
response_maybelline = requests.get('http://makeup-api.herokuapp.com/api/v1/products.json?brand=maybelline')

# %%
response_maybelline.status_code
# Out:
# 200

# %%
df_maybelline = pd.DataFrame(response_maybelline.json())
df_maybelline.head()
# Out:
#     id       brand                                               name  price  \
# 0  495  maybelline  Maybelline Face Studio Master Hi-Light Light B...  14.99
# 1  488  maybelline                          Maybelline Fit Me Bronzer  10.29
# 2  477  maybelline           Maybelline Facestudio Master Contour Kit  15.99
# 3  468  maybelline  Maybelline Face Studio Master Hi-Light Light B...  14.99
# 4  452  maybelline  Maybelline Face Studio Master Hi-Light Light B...  14.99
#
#   price_sign currency                                         image_link  \
# 0       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/991799...
# 1       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/d4f7d8...
# 2       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/4f731d...
# 3       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/462103...
# 4       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/e8c59b...
#
# ...

# %%
df_maybelline.to_csv('Maybelline.csv')

# %% [markdown]
# # MARCA 2 - ANABELLE

# %%
# annabelle
response_annabelle= requests.get('http://makeup-api.herokuapp.com/api/v1/products.json?brand=annabelle')
response_annabelle.status_code
# Out:
# 200

# %%
df_annabelle = pd.DataFrame(response_annabelle.json())
df_annabelle.head()
# Out:
#     id      brand                                      name  price price_sign  \
# 0  505  annabelle        Annabelle Biggy Bronzer Haute Gold  11.99       None
# 1  464  annabelle                          Annabelle Blush    7.99       None
# 2  399  annabelle  Annabelle Stay Sharp Waterproof Lipliner   9.99       None
# 3  332  annabelle             Annabelle SkinTrue Foundation  10.99       None
# 4  257  annabelle            Annabelle Retractable Eyeliner   9.99       None
#
#   currency                                         image_link  \
# 0     None  https://d3t32hsnjxo7q6.cloudfront.net/i/0bd612...
# 1     None  https://d3t32hsnjxo7q6.cloudfront.net/i/0af800...
# 2     None  https://d3t32hsnjxo7q6.cloudfront.net/i/bc487b...
# 3     None  https://d3t32hsnjxo7q6.cloudfront.net/i/c1b6c4...
# 4     None  https://d3t32hsnjxo7q6.cloudfront.net/i/d57955...
#
#                                         product_link     website_link  \
# ...

# %%
df_annabelle.to_csv('Anabelle.csv')

# %% [markdown]
# # MARCA 3 - REVLON

# %%
response_revlon= requests.get('http://makeup-api.herokuapp.com/api/v1/products.json?brand=revlon')
response_revlon.status_code
# Out:
# 200

# %%
df_revlon = pd.DataFrame(response_revlon.json())
df_revlon.head()
# Out:
#     id   brand                             name  price price_sign currency  \
# 0  453  revlon             Revlon Powder Blush   13.49       None     None
# 1  417  revlon    Revlon PhotoReady Cream Blush  13.49       None     None
# 2  412  revlon  Revlon Colorstay Moisture Stain  12.99       None     None
# 3  411  revlon     Revlon ColorBurst Balm Stain  11.49       None     None
# 4  394  revlon       Revlon ColorStay Lip Liner  11.49       None     None
#
#                                           image_link  \
# 0  https://d3t32hsnjxo7q6.cloudfront.net/i/dd6ee9...
# 1  https://d3t32hsnjxo7q6.cloudfront.net/i/1b84cb...
# 2  https://d3t32hsnjxo7q6.cloudfront.net/i/df00e1...
# 3  https://d3t32hsnjxo7q6.cloudfront.net/i/cf5419...
# 4  https://d3t32hsnjxo7q6.cloudfront.net/i/afcbc5...
#
#                                         product_link     website_link  \
# 0  https://well.ca/products/revlon-powder-blush_1...  https://well.ca
# ...

# %%
df_revlon.to_csv('Revlon.csv')

# %% [markdown]
# # MARCA 4 - CLINIQUE

# %%
response_clinique= requests.get('http://makeup-api.herokuapp.com/api/v1/products.json?brand=clinique')
response_clinique.status_code
# Out:
# 200

# %%
df_clinique = pd.DataFrame(response_clinique.json())
df_clinique.head()
# Out:
#     id     brand                                               name price  \
# 0  846  clinique  Even Better&trade; Compact Makeup Broad Spectr...  32.0
# 1  845  clinique  Redness Solutions Makeup<BR>Broad Spectrum SPF...  28.0
# 2  844  clinique                         Stay-Matte Oil-Free Makeup  26.0
# 3  843  clinique  Repairwear Laser Focus&trade; All-Smooth Makeu...  36.0
# 4  842  clinique               Perfectly Real&trade; Compact Makeup  28.0
#
#   price_sign currency                                         image_link  \
# 0          $      USD  https://www.clinique.com/media/export/cms/prod...
# 1          $      USD  https://www.clinique.com/media/export/cms/prod...
# 2          $      USD  https://www.clinique.com/media/export/cms/prod...
# 3          $      USD  https://www.clinique.com/media/export/cms/prod...
# 4          $      USD  https://www.clinique.com/media/export/cms/prod...
#
#                                         product_link  \
# ...

# %%
df_clinique.to_csv('Clinique.csv')

# %% [markdown]
# # MARCA 5 - BENEFIT

# %%
response_benefit= requests.get('http://makeup-api.herokuapp.com/api/v1/products.json?brand=benefit')
response_benefit.status_code
# Out:
# 200

# %%
df_benefit = pd.DataFrame(response_benefit.json())
df_benefit.head()
# Out:
#     id    brand                                 name price price_sign  \
# 0  644  benefit  the POREfessional: agent zero shine  39.0       None
# 1  643  benefit    hello flawless! powder foundation  44.0       None
# 2  641  benefit        dallas dusty rose face powder  36.0       None
# 3  640  benefit                            rockateur  36.0       None
# 4  639  benefit   cheekathon bronzer & blush palette  75.0       None
#
#   currency                                         image_link  \
# 0     None  https://www.benefitcosmetics.com/ca/sites/ca/f...
# 1     None  https://www.benefitcosmetics.com/ca/sites/ca/f...
# 2     None  https://www.benefitcosmetics.com/ca/sites/ca/f...
# 3     None  https://www.benefitcosmetics.com/ca/sites/ca/f...
# 4     None  https://www.benefitcosmetics.com/ca/sites/ca/f...
#
#                                         product_link  \
# 0  https://www.benefitcosmetics.com/ca/en-gb/prod...
# 1  https://www.benefitcosmetics.com/ca/en-gb/prod...
# ...

# %%
df_benefit.to_csv('Benefit.csv')

# %% [markdown]
# ## UNINDO OS DATAFRAMES

# %%
df_marcas = pd.concat([df_maybelline, df_annabelle, df_revlon, df_clinique,df_benefit])

# %%
df_marcas['brand_name'] = df_marcas ['brand']

# %%
df_marcas.head()
# Out:
#     id       brand                                               name  price  \
# 0  495  maybelline  Maybelline Face Studio Master Hi-Light Light B...  14.99
# 1  488  maybelline                          Maybelline Fit Me Bronzer  10.29
# 2  477  maybelline           Maybelline Facestudio Master Contour Kit  15.99
# 3  468  maybelline  Maybelline Face Studio Master Hi-Light Light B...  14.99
# 4  452  maybelline  Maybelline Face Studio Master Hi-Light Light B...  14.99
#
#   price_sign currency                                         image_link  \
# 0       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/991799...
# 1       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/d4f7d8...
# 2       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/4f731d...
# 3       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/462103...
# 4       None     None  https://d3t32hsnjxo7q6.cloudfront.net/i/e8c59b...
#
# ...

# %%
aux1 = df_marcas['brand'].value_counts().reset_index()

# %%
df_marcas_sum = pd.DataFrame (aux1)

# %%
df_marcas_sum.head()
# Out:
#         index  brand
# 0    clinique     93
# 1  maybelline     54
# 2     benefit     41
# 3      revlon     29
# 4   annabelle     11

# %%
df_marcas_sum.columns = ['nome_marca','total_produtos']

# %%
df_marcas_sum.head()
# Out:
#    nome_marca  total_produtos
# 0    clinique              93
# 1  maybelline              54
# 2     benefit              41
# 3      revlon              29
# 4   annabelle              11

# %% [markdown]
# # PLOTANDO O GRÁFICO

# %%
sns.barplot( x='nome_marca', y='total_produtos', data=df_marcas_sum)
# Out:
# <AxesSubplot:xlabel='nome_marca', ylabel='total_produtos'>
